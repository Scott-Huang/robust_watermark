# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt
from watermarker import Example_Watermarker
from metric import PSNR, SSIM, Stable_Diffussion, QMetric
from util import read_img

# %%
img = read_img('sample_imgs/s2.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
watermark = Example_Watermarker.create_watermark('Hello World', (150, 600))
watermarked_img = Example_Watermarker().watermark(img, (400, 100), watermark)
plt.imshow(watermarked_img)
plt.axis('off')
plt.show()
# Out:
# 598

# %%
watermark_mask = np.zeros(img.shape[:2], dtype=np.uint8)
watermark_mask[400:400+watermark.shape[0], 100:100+watermark.shape[1]] = 255
rmetric = Stable_Diffussion(None, PSNR())
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]

# %%
rmetric.show_inpaint(watermarked_img, watermark_mask)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=640x960>
